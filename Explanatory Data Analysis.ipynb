# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import warnings 
warnings.filterwarnings ("ignore")

# %%
lockdown=pd.read_csv('lockdown_dates_wikipedia.csv')
lockdown
# Out:
#     country_territory country_code                 place  \
# 0             Albania           AL               Albania
# 1             Algeria           DZ               Algiers
# 2             Algeria           DZ                 Blida
# 3           Argentina           AR  Greater Buenos Aires
# 4           Argentina           AR   Rest of the country
# ..                ...          ...                   ...
# 234           Vietnam           VN               Da Nang
# 235           Vietnam           VN             Hai Duong
# 236           Vietnam           VN              Bac Ninh
# 237           Vietnam           VN             Bac Giang
# 238          Zimbabwe           ZW              Zimbabwe
#
#     first_lockdown_start_date first_lockdown_end_date first_lockdown_length  \
# 0                  2020-03-13              2020-06-01                    80
# 1                  2020-03-23              2020-05-14                    52
# 2                  2020-03-23              2020-05-14                    52
# 3                  2020-03-19              2020-11-08                   234
# 4                  2020-03-19              2020-05-10                    52
# ..                        ...                     ...                   ...
# 234                       NaN                     NaN                    21
# 235                       NaN                     NaN                    21
# 236                       NaN                     NaN                    21
# 237                       NaN                     NaN                    21
# 238                2020-03-30              2020-05-02                    33
#
#     second_lockdown_start_date second_lockdown_end_date  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                   2021-05-22               2021-05-30
# 4                   2021-05-22               2021-05-30
# ..                         ...                      ...
# 234                 2020-07-28               2020-09-05
# 235                 2021-02-16               2021-03-02
# 236                 2021-05-18                      NaN
# 237                 2021-05-18                      NaN
# 238                        NaN                      NaN
#
#     second_lockdown_length third_lockdown_start_date  ...  \
# 0                      NaN                       NaN  ...
# 1                      NaN                       NaN  ...
# 2                      NaN                       NaN  ...
# 3                        9                2021-06-05  ...
# 4                        9                2021-06-05  ...
# ..                     ...                       ...  ...
# 234                     39                       NaN  ...
# 235                     14                       NaN  ...
# 236                     23                       NaN  ...
# 237                     23                       NaN  ...
# 238                    NaN                       NaN  ...
#
#     sixth_lockdown_end_date  sixth_lockdown_length  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN
# ..                      ...                    ...
# 234                     NaN                    NaN
# 235                     NaN                    NaN
# 236                     NaN                    NaN
# 237                     NaN                    NaN
# 238                     NaN                    NaN
#
#     seventh_lockdown_start_date seventh_lockdown_end_date  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ..                          ...                       ...
# 234                         NaN                       NaN
# 235                         NaN                       NaN
# 236                         NaN                       NaN
# 237                         NaN                       NaN
# 238                         NaN                       NaN
#
#      seventh_lockdown_length eighth_lockdown_start_date  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ..                       ...                        ...
# 234                      NaN                        NaN
# 235                      NaN                        NaN
# 236                      NaN                        NaN
# 237                      NaN                        NaN
# 238                      NaN                        NaN
#
#     eighth_lockdown_end_date  eighth_lockdown_length total_length  \
# 0                        NaN                     NaN           80
# 1                        NaN                     NaN           52
# 2                        NaN                     NaN           52
# 3                        NaN                     NaN          245
# 4                        NaN                     NaN           63
# ..                       ...                     ...          ...
# 234                      NaN                     NaN           60
# 235                      NaN                     NaN           35
# 236                      NaN                     NaN           23
# 237                      NaN                     NaN           23
# 238                      NaN                     NaN           33
#
#                                                  level
# 0                                             National
# 1                                                 City
# 2                                                 City
# 3                                    Metropolitan area
# 4                                             National
# ..                                                 ...
# 234                                               City
# 235  Province, Chi Linh city lockdown began from 28...
# 236                             4 districts and 1 city
# 237                                        6 districts
# 238                                           National
#
# [239 rows x 29 columns]

# %%
df2019Q1=pd.read_csv('2019Q1.csv',skiprows=4)
df2019Q2=pd.read_csv('2019Q2.csv',skiprows=4)
df2019Q3=pd.read_csv('2019Q3.csv',skiprows=4)
df2019Q4=pd.read_csv('2019Q2.csv',skiprows=4)
df2020Q1=pd.read_csv('2020Q1.csv',skiprows=4)
df2020Q2=pd.read_csv('2020Q2.csv',skiprows=4)
df2020Q3=pd.read_csv('2020Q3.csv',skiprows=4)
df2020Q4=pd.read_csv('2020Q4.csv',skiprows=4)
# 2021Q1 added for covering the lockdown dates
df2021Q1=pd.read_csv('waqi-covid19-airqualitydata-2021Q1.csv',skiprows=4)

# %%
df2020Q4
# Out:
#               Date Country         City Specie  count   min    max  median  \
# 0       2020-12-23      ET  Addis Ababa   pm25     24  30.0  167.0    46.0
# 1       2020-10-12      ET  Addis Ababa   pm25     24  55.0  119.0    68.0
# 2       2020-10-17      ET  Addis Ababa   pm25     24  50.0  153.0    72.0
# 3       2020-11-25      ET  Addis Ababa   pm25     23  42.0  137.0    68.0
# 4       2020-11-27      ET  Addis Ababa   pm25     24  30.0   82.0    46.0
# ...            ...     ...          ...    ...    ...   ...    ...     ...
# 586932  2020-12-31      PL       Kraków     o3    144   1.7    8.1     4.6
# 586933  2021-01-03      PL       Kraków     o3    144   0.5    7.1     2.1
# 586934  2020-10-12      PL       Kraków     o3    144   4.6   16.0    12.7
# 586935  2020-10-16      PL       Kraków     o3    144   1.2    5.9     3.5
# 586936  2020-10-30      PL       Kraków     o3    144   3.6   21.9     9.9
#
#         variance
# 0       20293.80
# 1        3372.88
# 2        4770.42
# 3        5971.58
# 4        1686.88
# ...          ...
# 586932     28.32
# 586933     30.05
# 586934     81.38
# 586935     18.86
# 586936    232.88
#
# [586937 rows x 9 columns]

# %%
df2021Q1.isna().sum()
# Out:
# Date        0
# Country     0
# City        0
# Specie      0
# count       0
# min         0
# max         0
# median      0
# variance    0
# dtype: int64

# %% [markdown]
# # EDA

# %%
Airquality2019_2020=pd.concat([df2019Q1,df2019Q2,df2019Q3,df2019Q4,df2020Q1,df2020Q2,df2020Q3,df2020Q4,df2021Q1],axis=0)
Airquality2019_2020
# Out:
#                Date Country       City Specie  count    min    max  median  \
# 0        2019-01-16      AE  Abu Dhabi   pm10     24   86.0   99.0    97.0
# 1        2019-01-22      AE  Abu Dhabi   pm10     24   51.0   57.0    55.0
# 2        2019-01-26      AE  Abu Dhabi   pm10     24  136.0  173.0   160.0
# 3        2019-01-07      AE  Abu Dhabi   pm10     24   60.0   91.0    72.0
# 4        2019-01-10      AE  Abu Dhabi   pm10     24   82.0   93.0    87.0
# ...             ...     ...        ...    ...    ...    ...    ...     ...
# 1834049  2021-06-07      PH  Zamboanga     co      3   11.2   11.2    11.2
# 1834050  2021-06-09      PH  Zamboanga     co      3   11.2   11.2    11.2
# 1834051  2021-06-18      PH  Zamboanga     co      3   11.2   11.2    11.2
# 1834052  2021-05-11      PH  Zamboanga    so2      2  149.9  258.2   149.9
# 1834053  2021-06-12      PH  Zamboanga    so2      2    2.1    6.6     2.1
#
#          variance
# 0          179.40
# 1           23.75
# 2          941.96
# 3         1006.88
# 4           57.97
# ...           ...
# 1834049      0.00
# 1834050      0.00
# 1834051      0.00
# 1834052  58644.40
# 1834053    101.25
#
# [6280759 rows x 9 columns]

# %%
Airquality2019_2020['Specie'].unique()
# Out:
# array(['pm10', 'humidity', 'o3', 'so2', 'wind-speed', 'wind-gust', 'dew',
#        'pm25', 'no2', 'pressure', 'temperature', 'precipitation', 'co',
#        'wd', 'uvi', 'aqi', 'pm1', 'mepaqi', 'pol', 'wind speed',
#        'wind gust', 'neph'], dtype=object)

# %% [markdown]
# ###### mean estimation

# %% [markdown]
# ###### Estimating the mean from the median, range, and the size of a sample
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1097734/
# let<br>
# a be min of the sample <br>
# b max of the sample <br>
# n size of the sample count <br>
# then <br>
# $\bar{x}=\frac{a+2m+b}{4} + \frac{a-2m +b }{4n}$(1)
# <br> if the size of the sample is fairly large the second fraction becomes negligible and the formula becomes <br>
# $\bar{x}=\frac{a+2m+b}{4}$ (2)<br>
# large simple size is greater than 30 https://www.statology.org/large-sample-condition/

# %%
df_grt30=Airquality2019_2020[Airquality2019_2020['count']>30]
df_ls30=Airquality2019_2020[Airquality2019_2020['count']<=30]

# %%
# estimating mean
df_grt30['mean']=(df_grt30['min'] +2*df_grt30['median'] + df_grt30['max'])/4
df_ls30['mean']=((df_ls30['min'] +2*df_ls30['median'] + df_ls30['max'])/4 )+(df_ls30['min']- 2*df_ls30['median'] + df_ls30['max'])/(4*df_ls30['count'])

# %%
df_2019_2020=pd.concat([df_ls30,df_grt30],axis=0)

# %%
df_2019_2020['Std']=np.sqrt(df_2019_2020['variance'])
df_2019_2020
# Out:
#                Date Country       City Specie  count    min    max  median  \
# 0        2019-01-16      AE  Abu Dhabi   pm10     24   86.0   99.0    97.0
# 1        2019-01-22      AE  Abu Dhabi   pm10     24   51.0   57.0    55.0
# 2        2019-01-26      AE  Abu Dhabi   pm10     24  136.0  173.0   160.0
# 3        2019-01-07      AE  Abu Dhabi   pm10     24   60.0   91.0    72.0
# 4        2019-01-10      AE  Abu Dhabi   pm10     24   82.0   93.0    87.0
# ...             ...     ...        ...    ...    ...    ...    ...     ...
# 1833530  2020-12-29      PH     Butuan   pm10     47    1.0   53.0    11.0
# 1833540  2020-12-30      PH     Butuan   pm10     48    1.0   71.0    10.0
# 1833545  2021-01-02      PH     Butuan   pm10     45    1.0   73.0    10.0
# 1833546  2021-01-03      PH     Butuan   pm10     36    1.0   26.0     5.0
# 1833547  2021-01-06      PH     Butuan   pm10     36    1.0   72.0     8.0
#
#          variance        mean        Std
# 0          179.40   94.656250  13.394029
# 1           23.75   54.479167   4.873397
# 2          941.96  157.135417  30.691367
# 3         1006.88   73.822917  31.731372
# 4           57.97   87.260417   7.613803
# ...           ...         ...        ...
# 1833530   2609.57   19.000000  51.083951
# 1833540   3240.78   23.000000  56.927849
# 1833545   3222.09   23.500000  56.763457
# 1833546    341.36    9.250000  18.475930
# 1833547   3592.85   22.250000  59.940387
#
# [6280759 rows x 11 columns]

# %% [markdown]
# Joining datasets

# %% [markdown]
# # INDIA

# %% [markdown]
# ### Airquality

# %%
df_2019_2020.rename(columns={'Country':'country_code'},inplace=True)

# %%
df_Airqualty_india=df_2019_2020[df_2019_2020['country_code']=='IN'].reset_index(drop=True)

# %%
df_Airqualty_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248624 entries, 0 to 248623
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          248624 non-null  object
#  1   country_code  248624 non-null  object
#  2   City          248624 non-null  object
#  3   Specie        248624 non-null  object
#  4   count         248624 non-null  int64
#  5   min           248624 non-null  float64
#  6   max           248624 non-null  float64
#  7   median        248624 non-null  float64
#  8   variance      248624 non-null  float64
#  9   mean          248624 non-null  float64
#  10  Std           248624 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 20.9+ MB

# %%
# converting dates to date time
df_Airqualty_india['Date'] = pd.to_datetime(df_Airqualty_india['Date'])

# %%
df_Airqualty_india['Specie'].unique()
# Out:
# array(['temperature', 'humidity', 'pm25', 'pressure', 'precipitation',
#        'o3', 'so2', 'wind-speed', 'dew', 'co', 'no2', 'pm10', 'wind-gust',
#        'wind speed', 'wind gust', 'wd'], dtype=object)

# %% [markdown]
# ###### let'us check the distribution of the estimated mean for each specie

# %%
def boxplot_by_specie(spec):
    df_Airqualty_india_specie=df_Airqualty_india.groupby('Specie')
    df_Airqualty_india_species=df_Airqualty_india_specie.get_group(spec)
    data=[df_Airqualty_india_species['mean'],df_Airqualty_india_species['median']]
    plt.figure(figsize = (15,15))
    plt.style.use('fivethirtyeight')
    plt.boxplot(data)
    plt.xticks([1, 2], ['mean', 'median'])
    plt.show()
    #['pm25','o3', 'so2', 'co', 'no2', 'pm10']
    return plt.show()

# %%
boxplot=boxplot_by_specie('pm25')

# %%
boxplot=boxplot_by_specie('o3')

# %%
boxplot=boxplot_by_specie('so2')

# %%
boxplot=boxplot_by_specie('co')

# %%
boxplot=boxplot_by_specie('no2')

# %%
boxplot=boxplot_by_specie('pm10')
boxplot

# %% [markdown]
# ## Visualization of cities by each species in India

# %%
#helper function
def topcity(spec):
    df_Airqualty_india_specie=df_Airqualty_india.groupby('Specie')
    df_Airqualty_india_species=df_Airqualty_india_specie.get_group(spec)
    myspecie=df_Airqualty_india_species.sort_values(by=['mean'],ascending=False)
    #graph of mean against city for selected specie
    plt.figure(figsize = (15,15))
    plt.style.use('fivethirtyeight')
    plt.bar(myspecie['City'],myspecie['mean'],color='b')
    #plt.errorbar(a, b, yerr=c, fmt="o", color="r")
    plt.title(f'{spec} by city in india')
    plt.xlabel('Cities')
    plt.ylabel(f'Mean of {spec}')
    plt.xticks(rotation=90) 
    plt.show()
    return plt.show()

# %%
#['pm25','o3', 'so2', 'co', 'no2', 'pm10']

# %%
graph=topcity('pm10')
graph

# %%
graph=topcity('o3')
graph

# %%
graph=topcity('pm25')
graph

# %%
graph=topcity('so2')
graph

# %%
graph=topcity('co')
graph

# %%
graph=topcity('no2')
graph

# %% [markdown]
# ##### Time series visualization for top 4 cities in each specie

# %%
def top4city(city,spec):
    df_Airqualty_india_specie=df_Airqualty_india.groupby('Specie')
    df_Airqualty_india_species=df_Airqualty_india_specie.get_group(spec)
    myspecie=df_Airqualty_india_species[df_Airqualty_india_species['City']==city]
    #graph of mean against city for selected specie
    plt.figure(figsize = (12,8))
    plt.style.use('fivethirtyeight')
    sns.lineplot(x=myspecie['Date'],y=myspecie['mean'],color='b',label=f'{spec}')
    plt.title(f'Time series of {spec} in {city} city')
    plt.xlabel('dates')
    plt.ylabel(f'Mean of {spec}')
    plt.xticks(rotation=90) 
    plt.show()
    return plt.show()

# %%
#top1 city in pm10
cities=top4city('Shillong','pm10')

# %%
#second city in pm10
cities=top4city('Ghāziābād','pm10')

# %%
#third city in pm10
cities=top4city('Muzaffarnagar','pm10')

# %%
#third city in pm10
cities=top4city('Delhi','pm10')

# %% [markdown]
# ###### o3

# %%
cities=top4city('Gandhinagar','o3')

# %%
cities=top4city('Visakhapatnam','o3')

# %%
cities=top4city('Delhi','o3')

# %%
cities=top4city('Mumbai','o3')

# %%
cities=top4city('Nagpur','pm25')

# %%
cities=top4city('Delhi','pm25')

# %%
cities=top4city('New Delhi','pm25')

# %%
cities=top4city('Patna','pm25')

# %%
cities=top4city('Visakhapatnam','so2')

# %%
cities=top4city('Mumbai','so2')

# %%
cities=top4city('Delhi','so2')

# %%
cities=top4city('Patna','so2')

# %%
cities=top4city('Visakhapatnam','co')

# %%
cities=top4city('Delhi','co')

# %%
cities=top4city('Mumbai','co')

# %%
cities=top4city('Thiruvananthapuram','co')

# %%
cities=top4city('Lucknow','no2')

# %%
cities=top4city('Hyderabad','no2')

# %%
cities=top4city('Delhi','no2')

# %%
cities=top4city('Ghāziābād','no2')

# %%
df_Airqualty_india['City'].unique()
# Out:
# array(['New Delhi', 'Delhi', 'Chandigarh', 'Bhopal', 'Ghāziābād', 'Hāpur',
#        'Gandhinagar', 'Chennai', 'Nashik', 'Visakhapatnam', 'Mumbai',
#        'Jaipur', 'Patna', 'Muzaffarnagar', 'Thiruvananthapuram',
#        'Bengaluru', 'Kolkata', 'Thrissur', 'Hyderabad', 'Lucknow',
#        'Shillong', 'Nagpur', 'Mysore'], dtype=object)

# %% [markdown]
# ### Lockdown_dataset

# %%
lockdown_india=lockdown[lockdown['country_territory']=='India'].reset_index(drop=True)
lockdown_india
# Out:
#   country_territory country_code          place first_lockdown_start_date  \
# 0             India           IN     Nationwide                2020-03-25
# 1             India           IN      Bengaluru                       NaN
# 2             India           IN          Delhi                       NaN
# 3             India           IN        Haryana                       NaN
# 4             India           IN    Maharashtra                       NaN
# 5             India           IN         Odisha                       NaN
# 6             India           IN      Rajasthan                       NaN
# 7             India           IN  Uttar Pradesh                       NaN
#
#   first_lockdown_end_date first_lockdown_length second_lockdown_start_date  \
# 0              2020-06-07                    74                        NaN
# 1                     NaN                   NaN                 2021-04-27
# 2                     NaN                   NaN                 2021-04-19
# 3                     NaN                   NaN                 2021-05-03
# 4                     NaN                   NaN                 2021-04-14
# 5                     NaN                   NaN                 2021-05-05
# 6                     NaN                   NaN                 2021-05-10
# 7                     NaN                   NaN                 2021-04-30
#
#   second_lockdown_end_date second_lockdown_length third_lockdown_start_date  \
# 0                      NaN                    NaN                       NaN
# 1               2021-05-09                     12                       NaN
# 2               2021-05-31                     42                       NaN
# 3               2021-05-10                      7                       NaN
# 4               2021-06-15                     62                       NaN
# 5               2021-05-19                     14                       NaN
# 6               2021-06-08                     29                       NaN
# 7               2021-05-10                     10                       NaN
#
#    ... sixth_lockdown_end_date  sixth_lockdown_length  \
# 0  ...                     NaN                    NaN
# 1  ...                     NaN                    NaN
# 2  ...                     NaN                    NaN
# 3  ...                     NaN                    NaN
# 4  ...                     NaN                    NaN
# 5  ...                     NaN                    NaN
# 6  ...                     NaN                    NaN
# 7  ...                     NaN                    NaN
#
#   seventh_lockdown_start_date seventh_lockdown_end_date  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
#
#    seventh_lockdown_length eighth_lockdown_start_date  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
# 5                      NaN                        NaN
# 6                      NaN                        NaN
# 7                      NaN                        NaN
#
#   eighth_lockdown_end_date  eighth_lockdown_length total_length     level
# 0                      NaN                     NaN           74  National
# 1                      NaN                     NaN           12    Region
# 2                      NaN                     NaN           42    Region
# 3                      NaN                     NaN            7     State
# 4                      NaN                     NaN           62     State
# 5                      NaN                     NaN           14     State
# 6                      NaN                     NaN           29     State
# 7                      NaN                     NaN           10     State
#
# [8 rows x 29 columns]

# %%
lockdown_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country_territory            8 non-null      object
#  1   country_code                 8 non-null      object
#  2   place                        8 non-null      object
#  3   first_lockdown_start_date    1 non-null      object
#  4   first_lockdown_end_date      1 non-null      object
#  5   first_lockdown_length        1 non-null      object
#  6   second_lockdown_start_date   7 non-null      object
#  7   second_lockdown_end_date     7 non-null      object
#  8   second_lockdown_length       7 non-null      object
#  9   third_lockdown_start_date    0 non-null      object
#  10  third_lockdown_end_date      0 non-null      object
#  11  third_lockdown_length        0 non-null      float64
#  12  fourth_lockdown_start_date   0 non-null      object
#  13  fourth_lockdown_end_date     0 non-null      object
#  14  fourth_lockdown_length       0 non-null      float64
#  15  fifth_lockdown_start_date    0 non-null      object
#  16  fifth_lockdown_end_date      0 non-null      object
#  17  fifth_lockdown_length        0 non-null      float64
#  18  sixth_lockdown_start_date    0 non-null      object
#  19  sixth_lockdown_end_date      0 non-null      object
#  20  sixth_lockdown_length        0 non-null      float64
#  21  seventh_lockdown_start_date  0 non-null      object
#  22  seventh_lockdown_end_date    0 non-null      object
#  23  seventh_lockdown_length      0 non-null      float64
#  24  eighth_lockdown_start_date   0 non-null      object
#  25  eighth_lockdown_end_date     0 non-null      object
#  26  eighth_lockdown_length       0 non-null      float64
#  27  total_length                 8 non-null      object
#  28  level                        8 non-null      object
# dtypes: float64(6), object(23)
# memory usage: 1.9+ KB

# %%
# let drop all column with zero non-null
lockdown_india.drop(['third_lockdown_start_date', 'third_lockdown_end_date',
       'third_lockdown_length', 'fourth_lockdown_start_date',
       'fourth_lockdown_end_date', 'fourth_lockdown_length',
       'fifth_lockdown_start_date', 'fifth_lockdown_end_date',
       'fifth_lockdown_length', 'sixth_lockdown_start_date',
       'sixth_lockdown_end_date', 'sixth_lockdown_length',
       'seventh_lockdown_start_date', 'seventh_lockdown_end_date',
       'seventh_lockdown_length', 'eighth_lockdown_start_date',
       'eighth_lockdown_end_date', 'eighth_lockdown_length'],inplace=True, axis=1)
lockdown_india
# Out:
#   country_territory country_code          place first_lockdown_start_date  \
# 0             India           IN     Nationwide                2020-03-25
# 1             India           IN      Bengaluru                       NaN
# 2             India           IN          Delhi                       NaN
# 3             India           IN        Haryana                       NaN
# 4             India           IN    Maharashtra                       NaN
# 5             India           IN         Odisha                       NaN
# 6             India           IN      Rajasthan                       NaN
# 7             India           IN  Uttar Pradesh                       NaN
#
#   first_lockdown_end_date first_lockdown_length second_lockdown_start_date  \
# 0              2020-06-07                    74                        NaN
# 1                     NaN                   NaN                 2021-04-27
# 2                     NaN                   NaN                 2021-04-19
# 3                     NaN                   NaN                 2021-05-03
# 4                     NaN                   NaN                 2021-04-14
# 5                     NaN                   NaN                 2021-05-05
# 6                     NaN                   NaN                 2021-05-10
# 7                     NaN                   NaN                 2021-04-30
#
#   second_lockdown_end_date second_lockdown_length total_length     level
# 0                      NaN                    NaN           74  National
# 1               2021-05-09                     12           12    Region
# 2               2021-05-31                     42           42    Region
# 3               2021-05-10                      7            7     State
# 4               2021-06-15                     62           62     State
# 5               2021-05-19                     14           14     State
# 6               2021-06-08                     29           29     State
# 7               2021-05-10                     10           10     State

# %%
lockdown_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   country_territory           8 non-null      object
#  1   country_code                8 non-null      object
#  2   place                       8 non-null      object
#  3   first_lockdown_start_date   1 non-null      object
#  4   first_lockdown_end_date     1 non-null      object
#  5   first_lockdown_length       1 non-null      object
#  6   second_lockdown_start_date  7 non-null      object
#  7   second_lockdown_end_date    7 non-null      object
#  8   second_lockdown_length      7 non-null      object
#  9   total_length                8 non-null      object
#  10  level                       8 non-null      object
# dtypes: object(11)
# memory usage: 832.0+ bytes

# %%
#converting date to dateformat
#df_2019_2020_lockdown_india['Date'] = pd.to_datetime(df_2019_2020_lockdown_india['Date'])
lockdown_india['first_lockdown_start_date'] = pd.to_datetime(lockdown_india['first_lockdown_start_date'])
lockdown_india['first_lockdown_end_date'] = pd.to_datetime(lockdown_india['first_lockdown_end_date'])
lockdown_india['second_lockdown_start_date'] = pd.to_datetime(lockdown_india['second_lockdown_start_date'])
lockdown_india['second_lockdown_end_date'] = pd.to_datetime(lockdown_india['second_lockdown_end_date'])
lockdown_india
# Out:
#   country_territory country_code          place first_lockdown_start_date  \
# 0             India           IN     Nationwide                2020-03-25
# 1             India           IN      Bengaluru                       NaT
# 2             India           IN          Delhi                       NaT
# 3             India           IN        Haryana                       NaT
# 4             India           IN    Maharashtra                       NaT
# 5             India           IN         Odisha                       NaT
# 6             India           IN      Rajasthan                       NaT
# 7             India           IN  Uttar Pradesh                       NaT
#
#   first_lockdown_end_date first_lockdown_length second_lockdown_start_date  \
# 0              2020-06-07                    74                        NaT
# 1                     NaT                   NaN                 2021-04-27
# 2                     NaT                   NaN                 2021-04-19
# 3                     NaT                   NaN                 2021-05-03
# 4                     NaT                   NaN                 2021-04-14
# 5                     NaT                   NaN                 2021-05-05
# 6                     NaT                   NaN                 2021-05-10
# 7                     NaT                   NaN                 2021-04-30
#
#   second_lockdown_end_date second_lockdown_length total_length     level
# 0                      NaT                    NaN           74  National
# 1               2021-05-09                     12           12    Region
# 2               2021-05-31                     42           42    Region
# 3               2021-05-10                      7            7     State
# 4               2021-06-15                     62           62     State
# 5               2021-05-19                     14           14     State
# 6               2021-06-08                     29           29     State
# 7               2021-05-10                     10           10     State

# %%
# converting lockdown length to float
lockdown_india['first_lockdown_length']=lockdown_india['first_lockdown_length'].astype(float)
lockdown_india['second_lockdown_length']=lockdown_india['second_lockdown_length'].astype(float)
lockdown_india['total_length']=lockdown_india['total_length'].astype(float)

# %%
lockdown_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   country_territory           8 non-null      object
#  1   country_code                8 non-null      object
#  2   place                       8 non-null      object
#  3   first_lockdown_start_date   1 non-null      datetime64[ns]
#  4   first_lockdown_end_date     1 non-null      datetime64[ns]
#  5   first_lockdown_length       1 non-null      float64
#  6   second_lockdown_start_date  7 non-null      datetime64[ns]
#  7   second_lockdown_end_date    7 non-null      datetime64[ns]
#  8   second_lockdown_length      7 non-null      float64
#  9   total_length                8 non-null      float64
#  10  level                       8 non-null      object
# dtypes: datetime64[ns](4), float64(3), object(4)
# memory usage: 832.0+ bytes

# %%
lockdown_india
# Out:
#   country_territory country_code          place first_lockdown_start_date  \
# 0             India           IN     Nationwide                2020-03-25
# 1             India           IN      Bengaluru                       NaT
# 2             India           IN          Delhi                       NaT
# 3             India           IN        Haryana                       NaT
# 4             India           IN    Maharashtra                       NaT
# 5             India           IN         Odisha                       NaT
# 6             India           IN      Rajasthan                       NaT
# 7             India           IN  Uttar Pradesh                       NaT
#
#   first_lockdown_end_date  first_lockdown_length second_lockdown_start_date  \
# 0              2020-06-07                   74.0                        NaT
# 1                     NaT                    NaN                 2021-04-27
# 2                     NaT                    NaN                 2021-04-19
# 3                     NaT                    NaN                 2021-05-03
# 4                     NaT                    NaN                 2021-04-14
# 5                     NaT                    NaN                 2021-05-05
# 6                     NaT                    NaN                 2021-05-10
# 7                     NaT                    NaN                 2021-04-30
#
#   second_lockdown_end_date  second_lockdown_length  total_length     level
# 0                      NaT                     NaN          74.0  National
# 1               2021-05-09                    12.0          12.0    Region
# 2               2021-05-31                    42.0          42.0    Region
# 3               2021-05-10                     7.0           7.0     State
# 4               2021-06-15                    62.0          62.0     State
# 5               2021-05-19                    14.0          14.0     State
# 6               2021-06-08                    29.0          29.0     State
# 7               2021-05-10                    10.0          10.0     State

# %% [markdown]
# ###### making species columns

# %%
df_Airqualty_india
# Out:
#              Date country_code       City       Specie  count   min   max  \
# 0      2019-01-25           IN  New Delhi  temperature     24   8.1  16.5
# 1      2019-03-15           IN  New Delhi  temperature     24  11.2  23.3
# 2      2019-01-05           IN  New Delhi  temperature     24   7.6  15.3
# 3      2019-01-19           IN  New Delhi  temperature     24   8.0  20.1
# 4      2019-03-21           IN  New Delhi  temperature     24  15.6  28.5
# ...           ...          ...        ...          ...    ...   ...   ...
# 248619 2021-09-12           IN    Kolkata           co    190   0.2  10.0
# 248620 2021-11-23           IN    Kolkata           co    204   1.6  30.2
# 248621 2021-01-11           IN    Kolkata           co    224   0.6  47.2
# 248622 2021-06-21           IN    Kolkata           co    239   0.4  29.2
# 248623 2021-07-15           IN    Kolkata           co    196   1.4  27.5
#
#         median  variance       mean        Std
# 0         10.9     70.07  11.629167   8.370783
# 1         15.5    199.22  16.411458  14.114532
# 2         10.8     82.07  11.138542   9.059249
# 3         10.7    194.17  12.444792  13.934490
# 4         19.3    219.36  20.732292  14.810807
# ...        ...       ...        ...        ...
# 248619     3.6     63.14   4.350000   7.946068
# 248620     9.1    246.45  12.500000  15.698726
# 248621     7.1    324.98  15.500000  18.027202
# 248622     4.8    166.80   9.800000  12.915107
# 248623     3.1     61.42   8.775000   7.837091
#
# [248624 rows x 11 columns]

# %%
df_Airqualty_india.columns
# Out:
# Index(['Date', 'country_code', 'City', 'Specie', 'count', 'min', 'max',
#        'median', 'variance', 'mean', 'Std'],
#       dtype='object')

# %%
df_Airqualty_india_new=df_Airqualty_india[['Date', 'country_code', 'City', 'Specie', 'mean']]

# %%
df_Airqualty_india_new
# Out:
#              Date country_code       City       Specie       mean
# 0      2019-01-25           IN  New Delhi  temperature  11.629167
# 1      2019-03-15           IN  New Delhi  temperature  16.411458
# 2      2019-01-05           IN  New Delhi  temperature  11.138542
# 3      2019-01-19           IN  New Delhi  temperature  12.444792
# 4      2019-03-21           IN  New Delhi  temperature  20.732292
# ...           ...          ...        ...          ...        ...
# 248619 2021-09-12           IN    Kolkata           co   4.350000
# 248620 2021-11-23           IN    Kolkata           co  12.500000
# 248621 2021-01-11           IN    Kolkata           co  15.500000
# 248622 2021-06-21           IN    Kolkata           co   9.800000
# 248623 2021-07-15           IN    Kolkata           co   8.775000
#
# [248624 rows x 5 columns]

# %%
table = pd.pivot_table(df_Airqualty_india_new, values='mean', index=['Date'],
                    columns=['Specie'])

# %%
table
# Out:
# Specie             co        dew   humidity        no2         o3        pm10  \
# Date
# 2018-12-31  17.835926   7.912105  54.878646  30.350157  22.190798  193.529647
# 2019-01-01  19.325919   8.301114  57.810251  31.396862  21.638907  207.191952
# 2019-01-02  17.086748   9.659149  58.672204  31.957523  21.457002  220.919872
# 2019-01-03  16.309120   9.645955  59.597204  30.154909  21.439854  214.220840
# 2019-01-04  13.888484  10.166876  60.578728  28.419578  20.672884  173.483173
# ...               ...        ...        ...        ...        ...         ...
# 2021-11-24  12.514226  16.280265  75.482473  22.971780  24.218655  142.119318
# 2021-11-25  13.691619  16.328801  95.591757  22.226278  23.298153  132.840909
# 2021-11-26  13.955114  15.899596  69.406884  22.366146  23.971181  152.351326
# 2021-11-27  13.355061  15.539038  69.638010  20.299432  28.494108  156.183239
# 2021-11-28  10.742325  16.335720  79.980019  15.535093  14.547120  134.240131
#
# Specie            pm25  precipitation     pressure        so2  temperature  \
# Date
# 2018-12-31  250.134320    -148.105263  1012.069917  13.186394    23.180181
# 2019-01-01  263.787376     187.309375  1010.671089  13.708485    23.220131
# 2019-01-02  253.207165     239.257812  1009.857775  12.940383    23.561842
# 2019-01-03  253.555850    -571.187500  1011.559827  13.715534    23.475822
# 2019-01-04  223.106360     185.173333  1011.546707  12.421296    23.460855
# ...                ...            ...          ...        ...          ...
# 2021-11-24  166.889946            NaN   859.535065  18.430161    43.353668
# 2021-11-25  177.521286            NaN   858.579778  14.849290    50.940164
# 2021-11-26  187.469656            NaN   856.185108  14.207365    48.639260
# 2021-11-27  186.510417            NaN   853.370146  14.813021    44.675612
# 2021-11-28  178.686407            NaN   847.788187   7.502119    46.020766
#
# Specie           wd  wind gust  wind speed  wind-gust  wind-speed
# Date
# 2018-12-31  205.750        NaN         NaN   9.335417    1.495544
# 2019-01-01  193.575        NaN         NaN   9.200000    1.631154
# 2019-01-02  173.275        NaN         NaN   8.200000    1.113252
# 2019-01-03  205.850        NaN         NaN   9.700000    1.315683
# 2019-01-04  193.250        NaN         NaN   9.200000    1.209201
# ...             ...        ...         ...        ...         ...
# 2021-11-24  159.700        NaN         NaN   9.025000    1.894550
# 2021-11-25  155.450        NaN         NaN  13.750000    1.908016
# 2021-11-26  163.000        NaN         NaN   9.000000    2.092754
# 2021-11-27  150.125        NaN         NaN   8.750000    1.947083
# 2021-11-28  134.375        NaN         NaN   7.104167    1.556574
#
# [957 rows x 16 columns]

# %%
table.columns
# Out:
# Index(['co', 'dew', 'humidity', 'no2', 'o3', 'pm10', 'pm25', 'precipitation',
#        'pressure', 'so2', 'temperature', 'wd', 'wind gust', 'wind speed',
#        'wind-gust', 'wind-speed'],
#       dtype='object', name='Specie')

# %%
table.drop(columns=['dew', 'humidity', 'precipitation',
       'pressure', 'temperature', 'wd', 'wind gust', 'wind speed',
       'wind-gust', 'wind-speed'],inplace=True)

# %%
table.isna().sum()
# Out:
# Specie
# co      0
# no2     0
# o3      0
# pm10    0
# pm25    0
# so2     0
# dtype: int64

# %%
table.head()
# Out:
# Specie             co        no2         o3        pm10        pm25        so2
# Date
# 2018-12-31  17.835926  30.350157  22.190798  193.529647  250.134320  13.186394
# 2019-01-01  19.325919  31.396862  21.638907  207.191952  263.787376  13.708485
# 2019-01-02  17.086748  31.957523  21.457002  220.919872  253.207165  12.940383
# 2019-01-03  16.309120  30.154909  21.439854  214.220840  253.555850  13.715534
# 2019-01-04  13.888484  28.419578  20.672884  173.483173  223.106360  12.421296

# %%
table.tail()
# Out:
# Specie             co        no2         o3        pm10        pm25        so2
# Date
# 2021-11-24  12.514226  22.971780  24.218655  142.119318  166.889946  18.430161
# 2021-11-25  13.691619  22.226278  23.298153  132.840909  177.521286  14.849290
# 2021-11-26  13.955114  22.366146  23.971181  152.351326  187.469656  14.207365
# 2021-11-27  13.355061  20.299432  28.494108  156.183239  186.510417  14.813021
# 2021-11-28  10.742325  15.535093  14.547120  134.240131  178.686407   7.502119

# %% [markdown]
# ###### Correlation between species

# %%
correlation=table.corr()
correlation
# Out:
# Specie        co       no2        o3      pm10      pm25       so2
# Specie
# co      1.000000  0.704972  0.170612  0.712467  0.709688  0.059483
# no2     0.704972  1.000000  0.296940  0.854214  0.888791  0.272169
# o3      0.170612  0.296940  1.000000  0.371239  0.331212  0.311448
# pm10    0.712467  0.854214  0.371239  1.000000  0.921630  0.284197
# pm25    0.709688  0.888791  0.331212  0.921630  1.000000  0.292667
# so2     0.059483  0.272169  0.311448  0.284197  0.292667  1.000000

# %%
plt.figure(figsize = (8,3))
plt.style.use('fivethirtyeight')
heat_map = sns.heatmap(correlation,annot=True,cmap="RdYlGn",)
plt.show()

# %%
def top4city(city,spec):
    df_Airqualty_india_specie=df_Airqualty_india.groupby('Specie')
    df_Airqualty_india_species=df_Airqualty_india_specie.get_group(spec)
    myspecie=df_Airqualty_india_species[df_Airqualty_india_species['City']==city]
    #graph of mean against city for selected specie
    plt.figure(figsize = (12,8))
    plt.style.use('fivethirtyeight')
    sns.lineplot(x=myspecie['Date'],y=myspecie['mean'],color='b',label=f'{spec}')
    plt.title(f'Time series of {spec} in {city} city')
    plt.xlabel('dates')
    plt.ylabel(f'Mean of {spec}')
    plt.xticks(rotation=90) 
    plt.show()
    return plt.show()

# %% [markdown]
# ###### Time series analysis for each specie

# %%
def specieSerie(spec):
    plt.figure(figsize = (15,8))
    sns.lineplot(x=table.index,y=table[spec],label=f'{spec}')
    #plt.vlines(x=(), ymin=0, ymax=, linewidth=2, color='g',linestyle='dashed')
    plt.title(f'Time series of {spec} in India')
    plt.xlabel('dates')
    plt.ylabel(f'{spec}')
    plt.xticks(rotation=90) 
    plt.show()
    return plt.show()

# %%
Species=specieSerie('co')

# %%
Species=specieSerie('no2')

# %%
Species=specieSerie('pm25')

# %%
Species=specieSerie('pm10')

# %%
Species=specieSerie('o3')

# %%
Species=specieSerie('so2')

# %% [markdown]
# #### Stationarity analysis

# %% [markdown]
# ###### processing lockdown dataset

# %%
lockdown_india
# Out:
#   country_territory country_code          place first_lockdown_start_date  \
# 0             India           IN     Nationwide                2020-03-25
# 1             India           IN      Bengaluru                       NaT
# 2             India           IN          Delhi                       NaT
# 3             India           IN        Haryana                       NaT
# 4             India           IN    Maharashtra                       NaT
# 5             India           IN         Odisha                       NaT
# 6             India           IN      Rajasthan                       NaT
# 7             India           IN  Uttar Pradesh                       NaT
#
#   first_lockdown_end_date  first_lockdown_length second_lockdown_start_date  \
# 0              2020-06-07                   74.0                        NaT
# 1                     NaT                    NaN                 2021-04-27
# 2                     NaT                    NaN                 2021-04-19
# 3                     NaT                    NaN                 2021-05-03
# 4                     NaT                    NaN                 2021-04-14
# 5                     NaT                    NaN                 2021-05-05
# 6                     NaT                    NaN                 2021-05-10
# 7                     NaT                    NaN                 2021-04-30
#
#   second_lockdown_end_date  second_lockdown_length  total_length     level
# 0                      NaT                     NaN          74.0  National
# 1               2021-05-09                    12.0          12.0    Region
# 2               2021-05-31                    42.0          42.0    Region
# 3               2021-05-10                     7.0           7.0     State
# 4               2021-06-15                    62.0          62.0     State
# 5               2021-05-19                    14.0          14.0     State
# 6               2021-06-08                    29.0          29.0     State
# 7               2021-05-10                    10.0          10.0     State

# %% [markdown]
# ###### Creating a new dataframe to holds lockdown dates

# %%
lockdown_india_new=pd.DataFrame()
lockdown_india_new['Date']=table.index
lockdown_india_new['lockdown']=0

# %% [markdown]
# ###### Lockdown range

# %%
FirstLockdown=list(pd.date_range(start='2020-03-25', end='2020-06-06'))
Secondlockdown=list(pd.date_range(start='2021-04-14', end='2021-06-14'))
lockdown1_2=FirstLockdown + Secondlockdown

# %% [markdown]
# ##### checking for lockdown dates in our dataframe

# %%
FirstL=lockdown_india_new[lockdown_india_new['Date'].isin(FirstLockdown)]
SecondL=lockdown_india_new[lockdown_india_new['Date'].isin(Secondlockdown)]
nolockdown=lockdown_india_new[~lockdown_india_new['Date'].isin(lockdown1_2)]

# %% [markdown]
# ###### filling 1 for lockdown date and 0 for nolockdown

# %%
FirstL['lockdown']=1
SecondL['lockdown']=1
nolockdown['lockdown']=0

# %%
Lockdown_df=pd.concat([FirstL,SecondL,nolockdown],axis=0)

# %%
#Lockdown_df['Date'].sort_values()
Lockdown_df.sort_values(by='Date',inplace=True)

# %%
Lockdown_df.head()
# Out:
#         Date  lockdown
# 0 2018-12-31         0
# 1 2019-01-01         0
# 2 2019-01-02         0
# 3 2019-01-03         0
# 4 2019-01-04         0

# %% [markdown]
# ###### Joining the two datasets

# %%
AirQ_df=table
AirQ_df.head()
# Out:
# Specie             co        no2         o3        pm10        pm25        so2
# Date
# 2018-12-31  17.835926  30.350157  22.190798  193.529647  250.134320  13.186394
# 2019-01-01  19.325919  31.396862  21.638907  207.191952  263.787376  13.708485
# 2019-01-02  17.086748  31.957523  21.457002  220.919872  253.207165  12.940383
# 2019-01-03  16.309120  30.154909  21.439854  214.220840  253.555850  13.715534
# 2019-01-04  13.888484  28.419578  20.672884  173.483173  223.106360  12.421296

# %%
AirQ_df.reset_index()
# Out:
# Specie       Date         co        no2         o3        pm10        pm25  \
# 0      2018-12-31  17.835926  30.350157  22.190798  193.529647  250.134320
# 1      2019-01-01  19.325919  31.396862  21.638907  207.191952  263.787376
# 2      2019-01-02  17.086748  31.957523  21.457002  220.919872  253.207165
# 3      2019-01-03  16.309120  30.154909  21.439854  214.220840  253.555850
# 4      2019-01-04  13.888484  28.419578  20.672884  173.483173  223.106360
# ..            ...        ...        ...        ...         ...         ...
# 952    2021-11-24  12.514226  22.971780  24.218655  142.119318  166.889946
# 953    2021-11-25  13.691619  22.226278  23.298153  132.840909  177.521286
# 954    2021-11-26  13.955114  22.366146  23.971181  152.351326  187.469656
# 955    2021-11-27  13.355061  20.299432  28.494108  156.183239  186.510417
# 956    2021-11-28  10.742325  15.535093  14.547120  134.240131  178.686407
#
# Specie        so2
# 0       13.186394
# 1       13.708485
# 2       12.940383
# 3       13.715534
# 4       12.421296
# ..            ...
# 952     18.430161
# 953     14.849290
# 954     14.207365
# 955     14.813021
# 956      7.502119
#
# [957 rows x 7 columns]

# %%
Merged_data=pd.merge(AirQ_df,Lockdown_df,on='Date',how='left')

# %%
Merged_data
# Out:
#           Date         co        no2         o3        pm10        pm25  \
# 0   2018-12-31  17.835926  30.350157  22.190798  193.529647  250.134320
# 1   2019-01-01  19.325919  31.396862  21.638907  207.191952  263.787376
# 2   2019-01-02  17.086748  31.957523  21.457002  220.919872  253.207165
# 3   2019-01-03  16.309120  30.154909  21.439854  214.220840  253.555850
# 4   2019-01-04  13.888484  28.419578  20.672884  173.483173  223.106360
# ..         ...        ...        ...        ...         ...         ...
# 952 2021-11-24  12.514226  22.971780  24.218655  142.119318  166.889946
# 953 2021-11-25  13.691619  22.226278  23.298153  132.840909  177.521286
# 954 2021-11-26  13.955114  22.366146  23.971181  152.351326  187.469656
# 955 2021-11-27  13.355061  20.299432  28.494108  156.183239  186.510417
# 956 2021-11-28  10.742325  15.535093  14.547120  134.240131  178.686407
#
#            so2  lockdown
# 0    13.186394         0
# 1    13.708485         0
# 2    12.940383         0
# 3    13.715534         0
# 4    12.421296         0
# ..         ...       ...
# 952  18.430161         0
# 953  14.849290         0
# 954  14.207365         0
# 955  14.813021         0
# 956   7.502119         0
#
# [957 rows x 8 columns]

# %% [markdown]
# ## Model
